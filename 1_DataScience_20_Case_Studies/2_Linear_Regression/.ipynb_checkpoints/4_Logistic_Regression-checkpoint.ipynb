# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

# %%
filename="./heights_weights.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#       Height      Weight  Male
# 0  73.847017  241.893563     1
# 1  68.781904  162.310473     1
# 2  74.110105  212.740856     1
# 3  71.730978  220.042470     1
# 4  69.881796  206.349801     1

# %%
df.shape
# Out:
# (10000, 3)

# %%
import seaborn as sns; sns.set()
ax = sns.scatterplot(x="Height", y="Weight",hue="Male",data=df)

# %%
x = df.iloc[:,0:2].values
y = df.iloc[:,2].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
clf = linear_model.LogisticRegression(C=1e40, solver='newton-cg')
fitted_model = clf.fit(X_train,Y_train)
height = 69
weight = 172
prediction = clf.predict([(height,weight)])
if prediction[0]:
    result = "male"
else:
    result = "female"
    
print("Person  is " + result)
# Out:
# Person  is male

# %%
print(fitted_model.intercept_)
# Out:
# [-0.03019374]

# %%
print(fitted_model.coef_)
# Out:
# [[-0.49519206  0.20348748]]

# %%
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='white')
xx, yy = np.mgrid[-5:5:.01,-5:5:.01]
grid = np.c_[xx.ravel(), yy.ravel()]

# %%
probs = clf.predict_proba(grid)[:,1].reshape(xx.shape)
f,ax = plt.subplots(figsize=(8,6))
contour = ax.contourf(xx,yy, probs,25,cmap="RdBu", vmin=0, vmax=1)
a_xc = f.colobar(contour)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-f88f3c8bd9e5> in <module>
#       2 f,ax = plt.subplots(figsize=(8,6))
#       3 contour = ax.contourf(xx,yy, probs,25,cmap="RdBu", vmin=0, vmax=1)
# ----> 4 a_xc = f.colobar(contour)
#       5
#
# AttributeError: 'Figure' object has no attribute 'colobar'
