# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_name ="./OnlineRetail.xlsx"
df = pd.read_excel(file_name, sheet_name="Online Retail")

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6 2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9 2010-12-01 08:34:00       1.69     13047.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df = df.loc[df['Quantity'] > 0]

# %%
df = df[pd.notnull(df['CustomerID'])]

# %%
print('Date Range : %s to %s ' % (df['InvoiceDate'].min(), df['InvoiceDate'].max()))
# Out:
# Date Range : 2010-12-01 08:26:00 to 2011-12-09 12:50:00

# %%
df['Sales'] = df['Quantity'] * df['UnitPrice']

# %%
orders_df = df.groupby(['CustomerID', 'InvoiceNo']).agg({'Sales': sum, 'InvoiceDate':max})

# %%
orders_df.head(10)
# Out:
#                          Sales         InvoiceDate
# CustomerID InvoiceNo
# 12346.0    541431     77183.60 2011-01-18 10:01:00
# 12347.0    537626       711.79 2010-12-07 14:57:00
#            542237       475.39 2011-01-26 14:30:00
#            549222       636.25 2011-04-07 10:43:00
#            556201       382.52 2011-06-09 13:01:00
#            562032       584.91 2011-08-02 08:48:00
#            573511      1294.32 2011-10-31 12:25:00
#            581180       224.82 2011-12-07 15:52:00
# 12348.0    539318       892.80 2010-12-16 19:09:00
#            541998       227.44 2011-01-25 10:42:00

# %%
def groupby_mean(x):
    return x.mean()

def groupby_count(x):
    return x.count()

def purchase_duration(x):
    return (x.max() - x.min()).days

def avg_frequency(x):
    return (x.max() - x.min()).days/x.count()

groupby_mean.__name__ ='avg'
groupby_count.__name__ ='count'
purchase_duration.__name__ ='purchase_duration'
avg_frequency.__name__ = 'avg_frequency'

summary_df = orders_df.reset_index().groupby('CustomerID').agg({
    'Sales':[min, max,sum,groupby_mean, groupby_count],
    'InvoiceDate':[min,max,purchase_duration, avg_frequency]
})

# %%
summary_df.head(10)
# Out:
#                Sales                                          \
#                  min       max       sum           avg count
# CustomerID
# 12346.0     77183.60  77183.60  77183.60  77183.600000   1.0
# 12347.0       224.82   1294.32   4310.00    615.714286   7.0
# 12348.0       227.44    892.80   1797.24    449.310000   4.0
# 12349.0      1757.55   1757.55   1757.55   1757.550000   1.0
# 12350.0       334.40    334.40    334.40    334.400000   1.0
# 12352.0       120.33    840.30   2506.04    313.255000   8.0
# 12353.0        89.00     89.00     89.00     89.000000   1.0
# 12354.0      1079.40   1079.40   1079.40   1079.400000   1.0
# 12355.0       459.40    459.40    459.40    459.400000   1.0
# 12356.0        58.35   2271.62   2811.43    937.143333   3.0
#
#                    InvoiceDate                                        \
#                            min                 max purchase_duration
# CustomerID
# 12346.0    2011-01-18 10:01:00 2011-01-18 10:01:00                 0
# 12347.0    2010-12-07 14:57:00 2011-12-07 15:52:00               365
# 12348.0    2010-12-16 19:09:00 2011-09-25 13:13:00               282
# 12349.0    2011-11-21 09:51:00 2011-11-21 09:51:00                 0
# 12350.0    2011-02-02 16:01:00 2011-02-02 16:01:00                 0
# 12352.0    2011-02-16 12:33:00 2011-11-03 14:37:00               260
# 12353.0    2011-05-19 17:47:00 2011-05-19 17:47:00                 0
# 12354.0    2011-04-21 13:11:00 2011-04-21 13:11:00                 0
# 12355.0    2011-05-09 13:49:00 2011-05-09 13:49:00                 0
# 12356.0    2011-01-18 09:50:00 2011-11-17 08:40:00               302
#
#
#            avg_frequency
# CustomerID
# 12346.0         0.000000
# 12347.0        52.142857
# 12348.0        70.500000
# 12349.0         0.000000
# 12350.0         0.000000
# 12352.0        32.500000
# 12353.0         0.000000
# 12354.0         0.000000
# 12355.0         0.000000
# 12356.0       100.666667

# %%
summary_df.columns = ['_'.join(col).lower() for col in summary_df.columns]

# %%
summary_df.head()
# Out:
#             sales_min  sales_max  sales_sum     sales_avg  sales_count  \
# CustomerID
# 12346.0      77183.60   77183.60   77183.60  77183.600000          1.0
# 12347.0        224.82    1294.32    4310.00    615.714286          7.0
# 12348.0        227.44     892.80    1797.24    449.310000          4.0
# 12349.0       1757.55    1757.55    1757.55   1757.550000          1.0
# 12350.0        334.40     334.40     334.40    334.400000          1.0
#
#                invoicedate_min     invoicedate_max  \
# CustomerID
# 12346.0    2011-01-18 10:01:00 2011-01-18 10:01:00
# 12347.0    2010-12-07 14:57:00 2011-12-07 15:52:00
# 12348.0    2010-12-16 19:09:00 2011-09-25 13:13:00
# 12349.0    2011-11-21 09:51:00 2011-11-21 09:51:00
# 12350.0    2011-02-02 16:01:00 2011-02-02 16:01:00
#
#             invoicedate_purchase_duration  invoicedate_avg_frequency
# CustomerID
# 12346.0                                 0                   0.000000
# 12347.0                               365                  52.142857
# 12348.0                               282                  70.500000
# 12349.0                                 0                   0.000000
# 12350.0                                 0                   0.000000

# %%
summary_df.groupby('sales_count').count()['sales_avg'][:20]
# Out:
# sales_count
# 1.0     1494
# 2.0      835
# 3.0      508
# 4.0      387
# 5.0      243
# 6.0      172
# 7.0      143
# 8.0       98
# 9.0       68
# 10.0      54
# 11.0      52
# 12.0      45
# 13.0      30
# 14.0      20
# 15.0      28
# 16.0      11
# 17.0      18
# 18.0      14
# 19.0      12
# 20.0      12
# Name: sales_avg, dtype: int64

# %%
summary_df = summary_df.loc[summary_df['invoicedate_purchase_duration'] > 0]

ax = summary_df.groupby('sales_count').count()['sales_avg'][:20].plot(kind='bar', color='skyblue', figsize=(12,7), grid=True)
ax.set_ylabel('count')
plt.show()

# %%
ax = summary_df['invoicedate_avg_frequency'].hist(bins=20, color='skyblue', figsize=(12,7),rwidth=0.7)
ax.set_xlabel('avg number of days between purchase')
ax.set_ylabel('count')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-9315e6f22018> in <module>
# ----> 1 ax = summary_df['invoicedate_avg_frequency'].hist(bin=20, color='skyblue', figsize=(12,7),rwidth=0.7)
#       2 ax.set_xlabel('avg number of days between purchase')
#       3 ax.set_ylabel('count')
#       4
#       5 plt.show()
#
# c:\program files\python37\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, **kwargs)
#      83         figsize=figsize,
#      84         bins=bins,
# ---> 85         **kwargs,
#      86     )
#      87
#
# c:\program files\python37\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#     307         values = self.dropna().values
#     308
# --> 309         ax.hist(values, bins=bins, **kwds)
#     310         ax.grid(grid)
#     311         axes = np.array([ax])
#
# c:\program files\python37\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\program files\python37\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6806             if patch:
#    6807                 p = patch[0]
# -> 6808                 p.update(kwargs)
#    6809                 if lbl is not None:
#    6810                     p.set_label(lbl)
#
# c:\program files\python37\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# c:\program files\python37\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# c:\program files\python37\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'Rectangle' object has no property 'bin'
